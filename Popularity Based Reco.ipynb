# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("rating_final.csv")
cusine = pd.read_csv("chefmozcuisine.csv")

# %%
data.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
cusine.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %%
rating_df = pd.DataFrame(data.groupby('placeID')['rating'].count())

rating_df = rating_df.sort_values(['rating'],ascending=False)

# %%
rating_df.reset_index(level=0,inplace=True)

# %%
final_dat = pd.merge(rating_df,cusine)

# %%
final_dat
# Out:
#      placeID  rating          Rcuisine
# 0     135085      36         Fast_Food
# 1     132825      32           Mexican
# 2     135032      28         Cafeteria
# 3     135032      28      Contemporary
# 4     135052      25               Bar
# 5     135052      25   Bar_Pub_Brewery
# 6     132834      25           Mexican
# 7     135060      22           Seafood
# 8     135042      20           Chinese
# 9     132862      18     International
# 10    135058      18          Pizzeria
# 11    132921      17               Bar
# 12    135041      17               Bar
# 13    135041      17         Cafeteria
# 14    135079      17           Chinese
# 15    135057      15               Bar
# 16    132572      15         Cafeteria
# 17    135025      15           Mexican
# 18    135028      15           Mexican
# 19    132856      14           Italian
# 20    132754      13           Mexican
# 21    135075      13           Seafood
# 22    135030      12  Cafe-Coffee_Shop
# ...

# %%
pd.Series.nunique(final_dat['Rcuisine'])
# Out:
# 23

# %%
cusine['Rcuisine'].describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object
